# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-159-g1d65a5a Python-3.10.11 torch-2.0.0+cu118 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.4/107.7 GB disk)

# %%
# !git clone https://github.com/Atharva309/trash_classification_data.git
# Out:
# Cloning into 'trash_classification_data'...
# remote: Enumerating objects: 3630, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3630 (delta 0), reused 3 (delta 0), pack-reused 3627
# Receiving objects: 100% (3630/3630), 62.63 MiB | 24.67 MiB/s, done.

# %%
from utils.downloads import attempt_download

p5 = ['n', 's', 'm', 'l', 'x']  # P5 models
cls = [f'{x}-cls' for x in p5]  # classification models

for x in cls:
    attempt_download(f'weights/yolov5{x}.pt')
# Out:
# ...
# 100%|██████████| 4.87M/4.87M [00:00<00:00, 11.0MB/s]
#
# ...
# 100%|██████████| 10.5M/10.5M [00:00<00:00, 18.6MB/s]
#
# ...
# 100%|██████████| 24.9M/24.9M [00:00<00:00, 76.0MB/s]
#
# ...
# 100%|██████████| 50.9M/50.9M [00:01<00:00, 42.5MB/s]
#
# ...
# 100%|██████████| 92.0M/92.0M [00:02<00:00, 44.3MB/s]

# %%
# !python /content/yolov5/classify/train.py --model yolov5n-cls.pt --data /content/yolov5/trash_classification_data/split_trash_data --epochs 100 --img 224 --pretrained weights/yolov5s-cls.pt
# Out:
# classify/train: model=yolov5n-cls.pt, data=/content/yolov5/trash_classification_data/split_trash_data, epochs=100, batch_size=64, imgsz=224, nosave=False, cache=None, device=, workers=8, project=yolov5/runs/train-cls, name=exp, exist_ok=False, pretrained=weights/yolov5s-cls.pt, optimizer=Adam, lr0=0.001, decay=5e-05, label_smoothing=0.1, cutoff=None, dropout=None, verbose=False, seed=0, local_rank=-1
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# requirements: /content/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-159-g1d65a5a Python-3.10.11 torch-2.0.0+cu118 CPU
#
# TensorBoard: Start with 'tensorboard --logdir yolov5/runs/train-cls', view at http://localhost:6006/
# ...

# %%
# !zip -r /content/weights_yolov5.zip /content/yolov5/runs
from google.colab import files
files.download('/content/weights_yolov5.zip')
# Out:
#   adding: content/yolov5/runs/ (stored 0%)
#   adding: content/yolov5/runs/train-cls/ (stored 0%)
#   adding: content/yolov5/runs/train-cls/exp/ (stored 0%)
#   adding: content/yolov5/runs/train-cls/exp/train_images.jpg (deflated 7%)
#   adding: content/yolov5/runs/train-cls/exp/results.csv (deflated 85%)
#   adding: content/yolov5/runs/train-cls/exp/test_images.jpg (deflated 8%)
#   adding: content/yolov5/runs/train-cls/exp/weights/ (stored 0%)
#   adding: content/yolov5/runs/train-cls/exp/weights/best.pt (deflated 10%)
#   adding: content/yolov5/runs/train-cls/exp/weights/last.pt (deflated 10%)
#   adding: content/yolov5/runs/train-cls/exp/events.out.tfevents.1682941458.f15322647f90.2065.0 (deflated 7%)
#   adding: content/yolov5/runs/train-cls/exp/opt.yaml (deflated 38%)

# %%
# !zip -r /content/entire_yolov5.zip /content/yolov5
from google.colab import files
files.download('/content/entire_yolov5.zip')
# Out:
#   adding: content/yolov5/ (stored 0%)
#   adding: content/yolov5/benchmarks.py (deflated 68%)
#   adding: content/yolov5/models/ (stored 0%)
#   adding: content/yolov5/models/tf.py (deflated 73%)
#   adding: content/yolov5/models/yolov5l.yaml (deflated 60%)
#   adding: content/yolov5/models/segment/ (stored 0%)
#   adding: content/yolov5/models/segment/yolov5s-seg.yaml (deflated 60%)
#   adding: content/yolov5/models/segment/yolov5x-seg.yaml (deflated 60%)
#   adding: content/yolov5/models/segment/yolov5m-seg.yaml (deflated 60%)
#   adding: content/yolov5/models/segment/yolov5n-seg.yaml (deflated 60%)
#   adding: content/yolov5/models/segment/yolov5l-seg.yaml (deflated 60%)
#   adding: content/yolov5/models/experimental.py (deflated 59%)
#   adding: content/yolov5/models/__init__.py (stored 0%)
#   adding: content/yolov5/models/yolov5m.yaml (deflated 60%)
#   adding: content/yolov5/models/hub/ (stored 0%)
#   adding: content/yolov5/models/hub/yolov3.yaml (deflated 63%)
# ...

# %%
#predict class for image
# !python /content/yolov5/classify/predict.py --weights /content/yolov5/runs/train-cls/exp/weights/best.pt --source /content/trash_classification/testtrash/trash114.jpg
# Out:
# classify/predict: weights=['/content/yolov5/runs/train-cls/exp/weights/best.pt'], source=/content/trash_classification/testtrash/trash114.jpg, data=yolov5/data/coco128.yaml, imgsz=[224, 224], device=, view_img=False, save_txt=False, nosave=False, augment=False, visualize=False, update=False, project=yolov5/runs/predict-cls, name=exp, exist_ok=False, half=False, dnn=False, vid_stride=1
# requirements: /content/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-159-g1d65a5a Python-3.10.11 torch-2.0.0+cu118 CPU
#
# Fusing layers...
# Model summary: 117 layers, 1217431 parameters, 0 gradients, 2.9 GFLOPs
# image 1/1 /content/trash_classification/testtrash/trash114.jpg: 224x224 plastic 0.36, metal 0.31, paper 0.18, glass 0.14, cardboard 0.02, 25.4ms
# Speed: 0.1ms pre-process, 25.4ms inference, 0.1ms NMS per image at shape (1, 3, 224, 224)
# Results saved to yolov5/runs/predict-cls/exp9

# %%
#using pretrained weights to predict class for image
# !python classify/predict.py --weights /content/best.pt --source /content/trash2.jpg

# %%
#using pretrained weights to continue training
# !python /content/yolov5/classify/train.py --model yolov5n-cls.pt --data /content/yolov5/trash_classification_data/split_trash_data --epochs 30 --img 224 --pretrained weights/yolov5s-cls.pt --pretrained /content/best.pt

# %%
# !unzip /content/drive/MyDrive/data/trash_classification.zip -d /content
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/trash_classification/cardboard/cardboard253.jpg
#   inflating: /content/__MACOSX/trash_classification/cardboard/._cardboard253.jpg
#   inflating: /content/trash_classification/cardboard/cardboard284.jpg
#   inflating: /content/__MACOSX/trash_classification/cardboard/._cardboard284.jpg
#   inflating: /content/trash_classification/cardboard/cardboard290.jpg
#   inflating: /content/__MACOSX/trash_classification/cardboard/._cardboard290.jpg
#   inflating: /content/trash_classification/cardboard/cardboard6.jpg
#   inflating: /content/__MACOSX/trash_classification/cardboard/._cardboard6.jpg
#   inflating: /content/trash_classification/cardboard/cardboard131.jpg
#   inflating: /content/__MACOSX/trash_classification/cardboard/._cardboard131.jpg
#   inflating: /content/trash_classification/cardboard/cardboard125.jpg
#   inflating: /content/__MACOSX/trash_classification/cardboard/._cardboard125.jpg
# ...
