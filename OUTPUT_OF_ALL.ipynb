# %%
# !git clone https://github.com/Atharva309/trash_classification_data.git
# Out:
# Cloning into 'trash_classification_data'...
# remote: Enumerating objects: 55212, done.
# remote: Counting objects: 100% (6598/6598), done.
# remote: Compressing objects: 100% (6557/6557), done.
# remote: Total 55212 (delta 39), reused 6598 (delta 39), pack-reused 48614
# Receiving objects: 100% (55212/55212), 719.18 MiB | 31.65 MiB/s, done.
# Resolving deltas: 100% (46/46), done.
# Updating files: 100% (54901/54901), done.

# %% [markdown]
# TEST ON CNN PRETRAINED MOBILENET MODEL FOR ORGANIC-INORGANIC

# %%
import cv2
from PIL import Image
import numpy as np
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras

# Load the model
model = load_model('/content/drive/MyDrive/data/O-R data weights/trash_image_classifier_mobilenet_O-R.h5')

# Get the class names from the data generator
class_names = list(test_data.class_indices.keys())

# Load and preprocess the image
img = Image.open('/content/trash_classification_data/organictrashdetection/TEST/O/O_12570.jpg')
img = img.resize((224, 224))
img_arr = np.array(img)
img_arr = img_arr.astype('float32') / 255.0
img_arr = np.expand_dims(img_arr, axis=0)

# Make a prediction
pred = model.predict(img_arr)
predicted_class = np.argmax(pred[0])
pred_class_name = class_names[predicted_class]

print("Predicted class:", str(predicted_class) + "-->" + pred_class_name)
print("")

plt.imshow(img)
plt.title(pred_class_name)
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 2s 2s/step
# Predicted class: 0-->O

# %%
from keras.preprocessing.image import ImageDataGenerator

batch_size = 32
img_height = 224
img_width = 224

# Load the test data using an ImageDataGenerator
test_datagen = ImageDataGenerator(rescale=1./255)
test_data = test_datagen.flow_from_directory(
    '/content/trash_classification_data/organictrashdetection/TEST',
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical')

# Evaluate the model on the test data
test_loss, test_acc = model.evaluate(test_data)

print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
# Out:
# Found 2513 images belonging to 2 classes.
# 79/79 [==============================] - 116s 1s/step - loss: 0.5322 - accuracy: 0.7959
# Test loss: 0.532209038734436
# Test accuracy: 0.795861542224884

# %% [markdown]
# TEST ON CNN PRETRAINED RESNET MODEL FOR ORGANIC INORGANIC

# %%
import cv2
from PIL import Image
import numpy as np
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras

# Load the model
model = load_model('/content/drive/MyDrive/data/O-R data weights/trash_image_classifier_resnet_O-R.h5')

# Get the class names from the data generator
class_names = list(test_data.class_indices.keys())

# Load and preprocess the image
img = Image.open('/content/trash_classification_data/organictrashdetection/TEST/R/R_10693.jpg')
img = img.resize((224, 224))
img_arr = np.array(img)
img_arr = img_arr.astype('float32') / 255.0
img_arr = np.expand_dims(img_arr, axis=0)

# Make a prediction
pred = model.predict(img_arr)
predicted_class = np.argmax(pred[0])
pred_class_name = class_names[predicted_class]

print("Predicted class:", str(predicted_class) + "-->" + pred_class_name)
print("")

plt.imshow(img)
plt.title(pred_class_name)
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 1s 1s/step
# Predicted class: 1-->R

# %%
from keras.preprocessing.image import ImageDataGenerator

batch_size = 32
img_height = 224
img_width = 224

# Load the test data using an ImageDataGenerator
test_datagen = ImageDataGenerator(rescale=1./255)
test_data = test_datagen.flow_from_directory(
    '/content/trash_classification_data/organictrashdetection/TEST',
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical')

# Evaluate the model on the test data
test_loss, test_acc = model.evaluate(test_data)

print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
# Out:
# Found 2513 images belonging to 2 classes.
# 79/79 [==============================] - 435s 5s/step - loss: 0.4432 - accuracy: 0.8774
# Test loss: 0.4431775212287903
# Test accuracy: 0.8774373531341553

# %% [markdown]
# TEST ON CNN PRETRAINED RESNET MODEL FOR DATA1

# %%
import cv2
from PIL import Image
import numpy as np
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt

#classes> 0-cardboard, 1-ewaste, 2-glass, 3-medical, 4-metal, 5-paper, 6-plastic

# Load the model
model = load_model('/content/drive/MyDrive/data/data1 weights/trash_image_classifier_regularized_final.h5')

# Load and preprocess the image
img = Image.open('/content/trash_classification_data/trash_classification/paper/paper1.jpg')
img = img.resize((224, 224))
img_arr = np.array(img)
img_arr = img_arr.astype('float32') / 255.0
img_arr = np.expand_dims(img_arr, axis=0)

# Make a prediction
pred = model.predict(img_arr)
predicted_class = np.argmax(pred[0])
pred_class_name = class_names[predicted_class]

print("Predicted class:", str(predicted_class) + "-->" + pred_class_name)
print("")

plt.imshow(img)
plt.title(pred_class_name)
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 1s 1s/step
# Predicted class: 5-->paper

# %%
# Load the test data using an ImageDataGenerator
test_datagen = ImageDataGenerator(rescale=1./255)
test_data = test_datagen.flow_from_directory(
    '/content/trash_classification_data/trash_classification',
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical')

# Evaluate the model on the test data
test_loss, test_acc = model.evaluate(test_data)

print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
# Out:
# Found 3629 images belonging to 7 classes.
# 114/114 [==============================] - 620s 5s/step - loss: 0.9591 - accuracy: 0.9124
# Test loss: 0.9591498970985413
# Test accuracy: 0.9123725295066833

# %% [markdown]
# yolov5 TEST on data1

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-162-gc3e4e94 Python-3.10.11 torch-2.0.0+cu118 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 25.0/107.7 GB disk)

# %%
from PIL import Image
import matplotlib.pyplot as plt

#using pretrained weights to predict class for image
# !python classify/predict.py --weights /content/content/yolov5/runs/train-cls/exp/weights/best.pt --source '/content/trash_classification_data/trash_classification/metal/metal101.jpg'

img = Image.open('/content/trash_classification_data/trash_classification/metal/metal101.jpg')
plt.imshow(img)
# plt.title(pred_class_name)
plt.axis('off')
plt.show()
# Out:
# classify/predict: weights=['/content/content/yolov5/runs/train-cls/exp/weights/best.pt'], source=/content/trash_classification_data/trash_classification/metal/metal101.jpg, data=data/coco128.yaml, imgsz=[224, 224], device=, view_img=False, save_txt=False, nosave=False, augment=False, visualize=False, update=False, project=runs/predict-cls, name=exp, exist_ok=False, half=False, dnn=False, vid_stride=1
# requirements: /content/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-162-gc3e4e94 Python-3.10.11 torch-2.0.0+cu118 CPU
#
# Fusing layers...
# Model summary: 117 layers, 1217431 parameters, 0 gradients, 2.9 GFLOPs
# image 1/1 /content/trash_classification_data/trash_classification/metal/metal101.jpg: 224x224 metal 0.99, paper 0.00, medical 0.00, cardboard 0.00, glass 0.00, 19.6ms
# Speed: 0.1ms pre-process, 19.6ms inference, 0.1ms NMS per image at shape (1, 3, 224, 224)
# Results saved to runs/predict-cls/exp10

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load image
image_path = '/content/content/yolov5/runs/train-cls/exp/test_images.jpg'
image = mpimg.imread(image_path)

# Show image
plt.imshow(image)
plt.show()

# %% [markdown]
# yolov5 test on data2

# %%
from PIL import Image
import matplotlib.pyplot as plt

#using pretrained weights to predict class for image
# !python classify/predict.py --weights '/content/drive/MyDrive/data/data2 weights/best21+35.pt' --source '/content/trash_classification_data/garbage_classification/clothes/clothes_10.jpg'

img = Image.open('/content/trash_classification_data/garbage_classification/clothes/clothes_10.jpg')
plt.imshow(img)
# plt.title(pred_class_name)
plt.axis('off')
plt.show()
# Out:
# classify/predict: weights=['/content/drive/MyDrive/data/data2 weights/best21+35.pt'], source=/content/trash_classification_data/garbage_classification/clothes/clothes_10.jpg, data=data/coco128.yaml, imgsz=[224, 224], device=, view_img=False, save_txt=False, nosave=False, augment=False, visualize=False, update=False, project=runs/predict-cls, name=exp, exist_ok=False, half=False, dnn=False, vid_stride=1
# requirements: /content/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-162-gc3e4e94 Python-3.10.11 torch-2.0.0+cu118 CPU
#
# Fusing layers...
# Model summary: 117 layers, 1222555 parameters, 0 gradients, 2.9 GFLOPs
# image 1/1 /content/trash_classification_data/garbage_classification/clothes/clothes_10.jpg: 224x224 clothes 0.85, hazardous 0.03, ewaste 0.02, shoes 0.02, medical 0.02, 21.6ms
# Speed: 0.1ms pre-process, 21.6ms inference, 0.1ms NMS per image at shape (1, 3, 224, 224)
# Results saved to runs/predict-cls/exp12

# %%
from PIL import Image
import matplotlib.pyplot as plt

#using pretrained weights to predict class for image
# !python classify/predict.py --weights '/content/drive/MyDrive/data/data2 weights/best21+35.pt' --source '/content/trash_classification_data/garbage_classification/hazardous/hazardous_102.jpg'

img = Image.open('/content/trash_classification_data/garbage_classification/hazardous/hazardous_102.jpg')
plt.imshow(img)
# plt.title(pred_class_name)
plt.axis('off')
plt.show()
# Out:
# classify/predict: weights=['/content/drive/MyDrive/data/data2 weights/best21+35.pt'], source=/content/trash_classification_data/garbage_classification/hazardous/hazardous_102.jpg, data=data/coco128.yaml, imgsz=[224, 224], device=, view_img=False, save_txt=False, nosave=False, augment=False, visualize=False, update=False, project=runs/predict-cls, name=exp, exist_ok=False, half=False, dnn=False, vid_stride=1
# requirements: /content/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-162-gc3e4e94 Python-3.10.11 torch-2.0.0+cu118 CPU
#
# Fusing layers...
# Model summary: 117 layers, 1222555 parameters, 0 gradients, 2.9 GFLOPs
# image 1/1 /content/trash_classification_data/garbage_classification/hazardous/hazardous_102.jpg: 224x224 hazardous 0.42, metal 0.31, plastic 0.12, cardboard 0.06, paper 0.04, 22.2ms
# Speed: 0.1ms pre-process, 22.2ms inference, 0.1ms NMS per image at shape (1, 3, 224, 224)
# Results saved to runs/predict-cls/exp13

# %%
from PIL import Image
import matplotlib.pyplot as plt

#using pretrained weights to predict class for image
# !python classify/predict.py --weights '/content/drive/MyDrive/data/data2 weights/best21+35.pt' --source '/content/trash_classification_data/garbage_classification/plastic/plastic1031.jpg'

img = Image.open('/content/trash_classification_data/garbage_classification/plastic/plastic1031.jpg')
plt.imshow(img)
# plt.title(pred_class_name)
plt.axis('off')
plt.show()
# Out:
# classify/predict: weights=['/content/drive/MyDrive/data/data2 weights/best21+35.pt'], source=/content/trash_classification_data/garbage_classification/plastic/plastic1031.jpg, data=data/coco128.yaml, imgsz=[224, 224], device=, view_img=False, save_txt=False, nosave=False, augment=False, visualize=False, update=False, project=runs/predict-cls, name=exp, exist_ok=False, half=False, dnn=False, vid_stride=1
# requirements: /content/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-162-gc3e4e94 Python-3.10.11 torch-2.0.0+cu118 CPU
#
# Fusing layers...
# Model summary: 117 layers, 1222555 parameters, 0 gradients, 2.9 GFLOPs
# image 1/1 /content/trash_classification_data/garbage_classification/plastic/plastic1031.jpg: 224x224 plastic 0.63, glass 0.20, shoes 0.06, cardboard 0.03, metal 0.03, 19.9ms
# Speed: 0.1ms pre-process, 19.9ms inference, 0.1ms NMS per image at shape (1, 3, 224, 224)
# Results saved to runs/predict-cls/exp17

# %%
from PIL import Image
import matplotlib.pyplot as plt

#using pretrained weights to predict class for image
# !python classify/predict.py --weights '/content/drive/MyDrive/data/data2 weights/best21+35.pt' --source '/content/trash_classification_data/garbage_classification/shoes/shoes_100.jpg'

img = Image.open('/content/trash_classification_data/garbage_classification/shoes/shoes_100.jpg')
plt.imshow(img)
# plt.title(pred_class_name)
plt.axis('off')
plt.show()
# Out:
# classify/predict: weights=['/content/drive/MyDrive/data/data2 weights/best21+35.pt'], source=/content/trash_classification_data/garbage_classification/shoes/shoes_100.jpg, data=data/coco128.yaml, imgsz=[224, 224], device=, view_img=False, save_txt=False, nosave=False, augment=False, visualize=False, update=False, project=runs/predict-cls, name=exp, exist_ok=False, half=False, dnn=False, vid_stride=1
# requirements: /content/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-162-gc3e4e94 Python-3.10.11 torch-2.0.0+cu118 CPU
#
# Fusing layers...
# Model summary: 117 layers, 1222555 parameters, 0 gradients, 2.9 GFLOPs
# image 1/1 /content/trash_classification_data/garbage_classification/shoes/shoes_100.jpg: 224x224 shoes 0.70, clothes 0.17, plastic 0.03, sanitary 0.02, metal 0.02, 20.1ms
# Speed: 0.1ms pre-process, 20.1ms inference, 0.1ms NMS per image at shape (1, 3, 224, 224)
# Results saved to runs/predict-cls/exp18

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load image
image_path = '/content/drive/MyDrive/data/data2 weights/test_images.jpg'
image = mpimg.imread(image_path)

# Show image
plt.imshow(image)
plt.show()
